# %% [markdown]
# ### Statistical Analysis ###

# %%
import pandas as pd
from statsmodels.stats.descriptivestats import describe
data = pd.read_csv(
    r"C:\Users\IFEOLUWA\Downloads\plane_new.csv"
)
data
describe(data["Price"])
# Out:
#                          Price
# nobs              10660.000000
# missing             616.000000
# mean               9044.411191
# std_err              44.624981
# upper_ci           9131.874547
# lower_ci           8956.947834
# std                4472.304869
# iqr                7096.250000
# iqr_normal         5260.457997
# mad                3626.231436
# mad_normal         4544.807123
# coef_var              0.494483
# range             53067.000000
# max               54826.000000
# min                1759.000000
# skew                  1.233970
# kurtosis              8.237594
# jarque_bera       14029.425314
# jarque_bera_pval      0.000000
# mode              10262.000000
# mode_freq             0.023497
# median             8366.000000
# 1%                 2227.000000
# 5%                 3543.000000
# 10%                3943.000000
# 25%                5276.750000
# 50%                8366.000000
# 75%               12373.000000
# 90%               14714.000000
# ...
